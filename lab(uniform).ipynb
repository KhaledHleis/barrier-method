# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

# %% [markdown]
# importing the data

# %%
HSI_Raw = sc.io.loadmat("Data\logreturn_SP500_2010_2013.mat")
print(HSI_Raw)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Apr 09 21:55:51 2014', '__version__': '1.0', '__globals__': [], 'Y': array([[-0.00618198,  0.01405552,  0.00066441, ...,  0.00761342,
#          0.00050551,  0.00590269],
#        [-0.02294252, -0.01364972,  0.00557493, ..., -0.00069064,
#          0.00285813,  0.0059854 ],
#        [ 0.0163127 , -0.00212427, -0.01959531, ..., -0.00117558,
#          0.00067193,  0.00552626],
#        ...,
#        [-0.01272226, -0.00708909, -0.00983028, ...,  0.00200022,
#          0.00774083,  0.00614981],
#        [ 0.00757359, -0.00348838, -0.02775496, ..., -0.00394381,
#         -0.00718803,  0.0059524 ],
#        [ 0.03506514,  0.08297097,  0.1061699 , ..., -0.00167926,
#          0.00201478,  0.00368325]])}

# %% [markdown]
# plotting

# %%
HSI = HSI_Raw['Y']
print(HSI.shape)
#read the last 30 days(from day -60 to day -30)
nb_days = HSI.shape[1]
nb_instances = HSI.shape[0]
HSI = np.exp(HSI)

HSI_train = HSI[: , 0:nb_days-30]
HSI_test = HSI[: , nb_days-30:nb_days]

plt.plot(HSI_test.T)
# Out:
# (162, 1005)
# ...

# %% [markdown]
# naiive aproach

# %%
#Wuniform
#print(HSI_test.shape)
#Wu = (1/nb_instances) *  np.ones(nb_instances)
#print(np.mean(HSI_test,axis=0))
XWu = np.mean(HSI_test,axis=0)
plt.plot(XWu)

# %% [markdown]
# estimate the variance

# %%
mean = np.mean(XWu)
print(mean)
var = np.sum(np.square(XWu - mean))/31
print(var)
# Out:
# 1.001034406204204
# 3.1539757222386333e-05

# %% [markdown]
# doing the same thing for all data
